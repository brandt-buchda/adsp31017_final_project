# %%
import pandas as pd

df_movies = pd.read_csv('data/rotten_tomatoes_movies.csv')
df_reviews = pd.read_csv('data/rotten_tomatoes_movie_reviews.csv')
df_wiki = pd.read_csv('data/wiki_movie_plots.csv')
df_metadata = pd.read_csv('data/movies_metadata.csv', low_memory=False)

# %%
def column_stats(df):
    stats = pd.DataFrame({
        "Data Type": df.dtypes,
        "Count": df.count(),
        "Missing Values": df.isna().sum(),
        "Missing Value Rate": df.isna().sum() / df.shape[0] * 100,
        "Unique Values": df.nunique(),
        "Unique Rate": df.nunique() / df.shape[0] * 100,
        "Mean": df.select_dtypes(include=["number"]).mean(),
        "Median": df.select_dtypes(include=["number"]).median(),
        "Mode": df.mode().iloc[0],
        "Min": df.select_dtypes(include=["number"]).min(),
        "Max": df.select_dtypes(include=["number"]).max(),
    })
    return stats

# %%
display(column_stats(df_movies))
display(column_stats(df_reviews))
display(column_stats(df_wiki))
display(column_stats(df_metadata))
# Out:
#                      Data Type   Count  Missing Values  Missing Value Rate  \
# audienceScore          float64   73248           70010           48.869871
# boxOffice               object   14743          128515           89.708777
# director                object  139041            4217            2.943640
# distributor             object   23001          120257           83.944352
# genre                   object  132175           11083            7.736392
# id                      object  143258               0            0.000000
# originalLanguage        object  129400           13858            9.673456
# rating                  object   13991          129267           90.233704
# ratingContents          object   13991          129267           90.233704
# releaseDateStreaming    object   79420           63838           44.561560
# releaseDateTheaters     object   30773          112485           78.519175
# runtimeMinutes         float64  129431           13827            9.651817
# soundMix                object   15917          127341           88.889277
# title                   object  142891             367            0.256181
# tomatoMeter            float64   33877          109381           76.352455
# writer                  object   90116           53142           37.095311
#
#                       Unique Values  Unique Rate       Mean  Median  \
# audienceScore                   101     0.070502  55.674967    57.0
# boxOffice                      4863     3.394575        NaN     NaN
# director                      62206    43.422357        NaN     NaN
# distributor                    3693     2.577867        NaN     NaN
# genre                          2912     2.032696        NaN     NaN
# id                           142052    99.158162        NaN     NaN
# originalLanguage                112     0.078181        NaN     NaN
# rating                           10     0.006980        NaN     NaN
# ratingContents                 8353     5.830739        NaN     NaN
# releaseDateStreaming           4726     3.298943        NaN     NaN
# releaseDateTheaters           12062     8.419774        NaN     NaN
# runtimeMinutes                  324     0.226165  93.708578    92.0
# soundMix                        551     0.384621        NaN     NaN
# title                        126403    88.234514        NaN     NaN
# tomatoMeter                     101     0.070502  65.770346    73.0
# writer                        67274    46.960030        NaN     NaN
#
#                                     Mode  Min     Max
# audienceScore                       50.0  0.0   100.0
# boxOffice                          $1.1M  NaN     NaN
# director                Unknown Director  NaN     NaN
# distributor           Paramount Pictures  NaN     NaN
# genre                              Drama  NaN     NaN
# id                              $5_a_day  NaN     NaN
# originalLanguage                 English  NaN     NaN
# rating                                 R  NaN     NaN
# ratingContents              ['Language']  NaN     NaN
# releaseDateStreaming          2017-05-22  NaN     NaN
# releaseDateTheaters           2018-09-14  NaN     NaN
# runtimeMinutes                      90.0  1.0  2700.0
# soundMix                        Surround  NaN     NaN
# title                         The Return  NaN     NaN
# tomatoMeter                        100.0  0.0   100.0
# writer                         Jing Wong  NaN     NaN
#                Data Type    Count  Missing Values  Missing Value Rate  \
# creationDate      object  1444963               0            0.000000
# criticName        object  1444963               0            0.000000
# id                object  1444963               0            0.000000
# isTopCritic         bool  1444963               0            0.000000
# originalScore     object  1009745          435218           30.119664
# publicatioName    object  1444963               0            0.000000
# reviewId           int64  1444963               0            0.000000
# reviewState       object  1444963               0            0.000000
# reviewText        object  1375738           69225            4.790780
# reviewUrl         object  1234038          210925           14.597260
# scoreSentiment    object  1444963               0            0.000000
#
#                 Unique Values  Unique Rate          Mean     Median  \
# creationDate             8510     0.588942           NaN        NaN
# criticName              15510     1.073384           NaN        NaN
# id                      69263     4.793410           NaN        NaN
# isTopCritic                 2     0.000138           NaN        NaN
# originalScore            1729     0.119657           NaN        NaN
# publicatioName           2707     0.187340           NaN        NaN
# reviewId              1432569    99.142262  9.035203e+06  2200337.0
# reviewState                 2     0.000138           NaN        NaN
# reviewText            1359771    94.104209           NaN        NaN
# reviewUrl             1138350    78.780564           NaN        NaN
# scoreSentiment              2     0.000138           NaN        NaN
#
#                                         Mode  Min          Max
# creationDate                      2000-01-01  NaN          NaN
# criticName                      Emanuel Levy  NaN          NaN
# id                             parasite_2019  NaN          NaN
# isTopCritic                            False  NaN          NaN
# originalScore                            3/5  NaN          NaN
# publicatioName                New York Times  NaN          NaN
# reviewId                                7726  1.0  102796154.0
# reviewState                            fresh  NaN          NaN
# reviewText           Parental Content Review  NaN          NaN
# reviewUrl       http://www.jackiekcooper.com  NaN          NaN
# scoreSentiment                      POSITIVE  NaN          NaN
#                  Data Type  Count  Missing Values  Missing Value Rate  \
# Cast                object  33464            1422            4.076134
# Director            object  34886               0            0.000000
# Genre               object  34886               0            0.000000
# Origin/Ethnicity    object  34886               0            0.000000
# Plot                object  34886               0            0.000000
# Release Year         int64  34886               0            0.000000
# Title               object  34886               0            0.000000
# Wiki Page           object  34886               0            0.000000
#
#                   Unique Values  Unique Rate         Mean  Median  \
# Cast                      32182    92.249040          NaN     NaN
# Director                  12593    36.097575          NaN     NaN
# Genre                      2265     6.492576          NaN     NaN
# Origin/Ethnicity             24     0.068796          NaN     NaN
# Plot                      33869    97.084790          NaN     NaN
# Release Year                117     0.335378  1981.314252  1988.0
# Title                     32432    92.965660          NaN     NaN
# Wiki Page                 34070    97.660953          NaN     NaN
#
#                                                                Mode     Min  \
# Cast                                                  Tom and Jerry     NaN
# Director                                                    Unknown     NaN
# Genre                                                       unknown     NaN
# Origin/Ethnicity                                           American     NaN
# Plot              (マッスル人参争奪！超人大戦争, Massuru Ninjin Soudatsu! Chou...     NaN
# Release Year                                                 2013.0  1901.0
# Title                                                    Cinderella     NaN
# Wiki Page         https://en.wikipedia.org/wiki/Digimon_Adventur...     NaN
#
#                      Max
# Cast                 NaN
# Director             NaN
# Genre                NaN
# Origin/Ethnicity     NaN
# Plot                 NaN
# Release Year      2017.0
# Title                NaN
# Wiki Page            NaN
#                       Data Type  Count  Missing Values  Missing Value Rate  \
# adult                    object  45466               0            0.000000
# belongs_to_collection    object   4494           40972           90.115691
# budget                   object  45466               0            0.000000
# genres                   object  45466               0            0.000000
# homepage                 object   7782           37684           82.883913
# id                       object  45466               0            0.000000
# imdb_id                  object  45449              17            0.037391
# original_language        object  45455              11            0.024194
# original_title           object  45466               0            0.000000
# overview                 object  44512             954            2.098271
# popularity               object  45461               5            0.010997
# poster_path              object  45080             386            0.848986
# production_companies     object  45463               3            0.006598
# production_countries     object  45463               3            0.006598
# release_date             object  45379              87            0.191352
# revenue                 float64  45460               6            0.013197
# runtime                 float64  45203             263            0.578454
# spoken_languages         object  45460               6            0.013197
# status                   object  45379              87            0.191352
# tagline                  object  20412           25054           55.104914
# title                    object  45460               6            0.013197
# video                    object  45460               6            0.013197
# vote_average            float64  45460               6            0.013197
# vote_count              float64  45460               6            0.013197
#
#                        Unique Values  Unique Rate          Mean  Median  \
# adult                              5     0.010997           NaN     NaN
# belongs_to_collection           1698     3.734659           NaN     NaN
# budget                          1226     2.696520           NaN     NaN
# genres                          4069     8.949545           NaN     NaN
# homepage                        7673    16.876347           NaN     NaN
# id                             45436    99.934017           NaN     NaN
# imdb_id                        45417    99.892227           NaN     NaN
# original_language                 92     0.202349           NaN     NaN
# original_title                 43373    95.396560           NaN     NaN
# overview                       44307    97.450842           NaN     NaN
# popularity                     43758    96.243347           NaN     NaN
# poster_path                    45024    99.027845           NaN     NaN
# production_companies           22708    49.945014           NaN     NaN
# production_countries            2393     5.263274           NaN     NaN
# release_date                   17336    38.129591           NaN     NaN
# revenue                         6863    15.094796  1.120935e+07     0.0
# runtime                          353     0.776404  9.412820e+01    95.0
# spoken_languages                1931     4.247130           NaN     NaN
# status                             6     0.013197           NaN     NaN
# tagline                        20283    44.611358           NaN     NaN
# title                          42277    92.985968           NaN     NaN
# video                              2     0.004399           NaN     NaN
# vote_average                      92     0.202349  5.618207e+00     6.0
# vote_count                      1820     4.002991  1.098973e+02    10.0
#
#                                                                     Mode  Min  \
# adult                                                              False  NaN
# belongs_to_collection  {'id': 415931, 'name': 'The Bowery Boys', 'pos...  NaN
# budget                                                                 0  NaN
# genres                                     [{'id': 18, 'name': 'Drama'}]  NaN
# homepage                                     http://www.georgecarlin.com  NaN
# id                                                                141971  NaN
# imdb_id                                                                0  NaN
# original_language                                                     en  NaN
# original_title                                       Alice in Wonderland  NaN
# overview                                              No overview found.  NaN
# popularity                                                           0.0  NaN
# poster_path                             /5D7UBSEgdyONE6Lql6xS7s6OLcW.jpg  NaN
# production_companies                                                  []  NaN
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...  NaN
# release_date                                                  2008-01-01  NaN
# revenue                                                              0.0  0.0
# runtime                                                             90.0  0.0
# spoken_languages                [{'iso_639_1': 'en', 'name': 'English'}]  NaN
# status                                                          Released  NaN
# tagline                                           Based on a true story.  NaN
# title                                                         Cinderella  NaN
# video                                                              False  NaN
# vote_average                                                         0.0  0.0
# vote_count                                                           1.0  0.0
#
#                                 Max
# adult                           NaN
# belongs_to_collection           NaN
# budget                          NaN
# genres                          NaN
# homepage                        NaN
# id                              NaN
# imdb_id                         NaN
# original_language               NaN
# original_title                  NaN
# overview                        NaN
# popularity                      NaN
# poster_path                     NaN
# production_companies            NaN
# production_countries            NaN
# release_date                    NaN
# revenue                2.787965e+09
# runtime                1.256000e+03
# spoken_languages                NaN
# status                          NaN
# tagline                         NaN
# title                           NaN
# video                           NaN
# vote_average           1.000000e+01
# vote_count             1.407500e+04

# %%
df_movies["title"] = df_movies["title"].str.strip().str.lower()
df_wiki["title"] = df_wiki["Title"].str.strip().str.lower()
df_metadata["title"] = df_metadata["title"].str.strip().str.lower()

# Merge DataFrames on the cleaned title column using inner joins
df_joined = (
    df_movies
    .merge(df_wiki, on=["title" , ], how="inner")
    .merge(df_metadata, on=["title"], how="inner")
)

review_counts = df_reviews.groupby('id').size().reset_index(name='review_count')
df_joined = df_joined.merge(review_counts, left_on='id_x', right_on='id', how='left')

df_joined.head()
print(df_joined.shape)
# Out:
# (49763, 49)

# %%
display(column_stats(df_joined))
# Out:
#                       Data Type  Count  Missing Values  Missing Value Rate  \
# Cast                     object  48101            1662            3.339831
# Director                 object  49763               0            0.000000
# Genre                    object  49763               0            0.000000
# Origin/Ethnicity         object  49763               0            0.000000
# Plot                     object  49763               0            0.000000
# Release Year              int64  49763               0            0.000000
# Title                    object  49763               0            0.000000
# Wiki Page                object  49763               0            0.000000
# adult                    object  49763               0            0.000000
# audienceScore           float64  37680           12083           24.281092
# belongs_to_collection    object   3828           45935           92.307538
# boxOffice                object  12019           37744           75.847517
# budget                   object  49763               0            0.000000
# director                 object  48884             879            1.766373
# distributor              object  16970           32793           65.898358
# genre                    object  48231            1532            3.078593
# genres                   object  49763               0            0.000000
# homepage                 object   7672           42091           84.582923
# id                       object  34880           14883           29.907763
# id_x                     object  49763               0            0.000000
# id_y                     object  49763               0            0.000000
# imdb_id                  object  49747              16            0.032152
# originalLanguage         object  46519            3244            6.518900
# original_language        object  49762               1            0.002010
# original_title           object  49763               0            0.000000
# overview                 object  49475             288            0.578743
# popularity               object  49763               0            0.000000
# poster_path              object  49701              62            0.124591
# production_companies     object  49763               0            0.000000
# production_countries     object  49763               0            0.000000
# rating                   object   8862           40901           82.191588
# ratingContents           object   8862           40901           82.191588
# releaseDateStreaming     object  36086           13677           27.484275
# releaseDateTheaters      object  20831           28932           58.139582
# release_date             object  49759               4            0.008038
# revenue                 float64  49763               0            0.000000
# review_count            float64  34880           14883           29.907763
# runtime                 float64  49754               9            0.018086
# runtimeMinutes          float64  47701            2062            4.143641
# soundMix                 object  12837           36926           74.203726
# spoken_languages         object  49763               0            0.000000
# status                   object  49706              57            0.114543
# tagline                  object  29441           20322           40.837570
# title                    object  49763               0            0.000000
# tomatoMeter             float64  23514           26249           52.748026
# video                    object  49763               0            0.000000
# vote_average            float64  49763               0            0.000000
# vote_count              float64  49763               0            0.000000
# writer                   object  35212           14551           29.240600
#
#                        Unique Values  Unique Rate          Mean  Median  \
# Cast                           15068    30.279525           NaN     NaN
# Director                        6213    12.485180           NaN     NaN
# Genre                           1240     2.491811           NaN     NaN
# Origin/Ethnicity                  20     0.040191           NaN     NaN
# Plot                           15397    30.940659           NaN     NaN
# Release Year                     113     0.227076  1.981188e+03  1990.0
# Title                          14015    28.163495           NaN     NaN
# Wiki Page                      15421    30.988887           NaN     NaN
# adult                              1     0.002010           NaN     NaN
# audienceScore                    100     0.200953  5.723769e+01    59.0
# belongs_to_collection            934     1.876896           NaN     NaN
# boxOffice                       2718     5.461889           NaN     NaN
# budget                           750     1.507144           NaN     NaN
# director                        9603    19.297470           NaN     NaN
# distributor                     1556     3.126821           NaN     NaN
# genre                           1059     2.128087           NaN     NaN
# genres                          2387     4.796737           NaN     NaN
# homepage                        2554     5.132327           NaN     NaN
# id                             16353    32.861765           NaN     NaN
# id_x                           21041    42.282419           NaN     NaN
# id_y                           16396    32.948174           NaN     NaN
# imdb_id                        16392    32.940136           NaN     NaN
# originalLanguage                  83     0.166791           NaN     NaN
# original_language                 53     0.106505           NaN     NaN
# original_title                 14748    29.636477           NaN     NaN
# overview                       16339    32.833631           NaN     NaN
# popularity                     16307    32.769327           NaN     NaN
# poster_path                    16379    32.914012           NaN     NaN
# production_companies            9214    18.515765           NaN     NaN
# production_countries             856     1.720154           NaN     NaN
# rating                             7     0.014067           NaN     NaN
# ratingContents                  3383     6.798224           NaN     NaN
# releaseDateStreaming            2818     5.662842           NaN     NaN
# releaseDateTheaters             6017    12.091313           NaN     NaN
# release_date                   10029    20.153528           NaN     NaN
# revenue                         4957     9.961216  2.544077e+07     0.0
# review_count                     376     0.755581  3.899774e+01    11.0
# runtime                          250     0.502381  1.022469e+02    99.0
# runtimeMinutes                   227     0.456162  9.945131e+01    97.0
# soundMix                         459     0.922372           NaN     NaN
# spoken_languages                 928     1.864839           NaN     NaN
# status                             5     0.010048           NaN     NaN
# tagline                        10897    21.897796           NaN     NaN
# title                          13948    28.028857           NaN     NaN
# tomatoMeter                      101     0.202962  6.242285e+01    68.0
# video                              2     0.004019           NaN     NaN
# vote_average                      84     0.168800  5.869751e+00     6.1
# vote_count                      1673     3.361936  2.040667e+02    17.0
# writer                         12476    25.070836           NaN     NaN
#
#                                                                     Mode  \
# Cast                   Kenneth Branagh, Derek Jacobi, Julie Christie,...
# Director                                                         Unknown
# Genre                                                              drama
# Origin/Ethnicity                                                American
# Plot                   After losing her mother at a young age, Ella p...
# Release Year                                                      2012.0
# Title                                                         Cinderella
# Wiki Page              https://en.wikipedia.org/wiki/Cinderella_(2015...
# adult                                                              False
# audienceScore                                                       50.0
# belongs_to_collection  {'id': 87631, 'name': 'The Musketeers Collecti...
# boxOffice                                                          $1.1M
# budget                                                                 0
# director                                                Unknown Director
# distributor                                           Paramount Pictures
# genre                                                              Drama
# genres                                     [{'id': 18, 'name': 'Drama'}]
# homepage                   http://movies.disney.com/the-three-musketeers
# id                                                    1138195-cinderella
# id_x                                                  1138195-cinderella
# id_y                                                               10057
# imdb_id                                                        tt0012752
# originalLanguage                                                 English
# original_language                                                     en
# original_title                                      The Three Musketeers
# overview               Miser Ebenezer Scrooge is awakened on Christma...
# popularity                                                      0.000431
# poster_path                             /cQsjMRId7r61Nh0bwEtGzCvp9gS.jpg
# production_companies                                                  []
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...
# rating                                                                 R
# ratingContents                                              ['Language']
# releaseDateStreaming                                          2017-05-22
# releaseDateTheaters                                           1996-12-25
# release_date                                                  1997-01-01
# revenue                                                              0.0
# review_count                                                         1.0
# runtime                                                             90.0
# runtimeMinutes                                                      90.0
# soundMix                                                        Surround
# spoken_languages                [{'iso_639_1': 'en', 'name': 'English'}]
# status                                                          Released
# tagline                               . . . One for All and All for Fun!
# title                                                         cinderella
# tomatoMeter                                                        100.0
# video                                                              False
# vote_average                                                         6.0
# vote_count                                                           2.0
# writer                                                       Paul Leadon
#
#                           Min           Max
# Cast                      NaN           NaN
# Director                  NaN           NaN
# Genre                     NaN           NaN
# Origin/Ethnicity          NaN           NaN
# Plot                      NaN           NaN
# Release Year           1902.0  2.017000e+03
# Title                     NaN           NaN
# Wiki Page                 NaN           NaN
# adult                     NaN           NaN
# audienceScore             0.0  1.000000e+02
# belongs_to_collection     NaN           NaN
# boxOffice                 NaN           NaN
# budget                    NaN           NaN
# director                  NaN           NaN
# distributor               NaN           NaN
# genre                     NaN           NaN
# genres                    NaN           NaN
# homepage                  NaN           NaN
# id                        NaN           NaN
# id_x                      NaN           NaN
# id_y                      NaN           NaN
# imdb_id                   NaN           NaN
# originalLanguage          NaN           NaN
# original_language         NaN           NaN
# original_title            NaN           NaN
# overview                  NaN           NaN
# popularity                NaN           NaN
# poster_path               NaN           NaN
# production_companies      NaN           NaN
# production_countries      NaN           NaN
# rating                    NaN           NaN
# ratingContents            NaN           NaN
# releaseDateStreaming      NaN           NaN
# releaseDateTheaters       NaN           NaN
# release_date              NaN           NaN
# revenue                   0.0  2.787965e+09
# review_count              1.0  9.540000e+02
# runtime                   0.0  8.770000e+02
# runtimeMinutes            2.0  4.850000e+02
# soundMix                  NaN           NaN
# spoken_languages          NaN           NaN
# status                    NaN           NaN
# tagline                   NaN           NaN
# title                     NaN           NaN
# tomatoMeter               0.0  1.000000e+02
# video                     NaN           NaN
# vote_average              0.0  1.000000e+01
# vote_count                0.0  1.407500e+04
# writer                    NaN           NaN

# %%
df_joined.dropna(subset=['boxOffice'], inplace=True)

# %%
display(column_stats(df_joined))
# Out:
#                       Data Type  Count  Missing Values  Missing Value Rate  \
# Cast                     object  11735             284            2.362925
# Director                 object  12019               0            0.000000
# Genre                    object  12019               0            0.000000
# Origin/Ethnicity         object  12019               0            0.000000
# Plot                     object  12019               0            0.000000
# Release Year              int64  12019               0            0.000000
# Title                    object  12019               0            0.000000
# Wiki Page                object  12019               0            0.000000
# adult                    object  12019               0            0.000000
# audienceScore           float64  11924              95            0.790415
# belongs_to_collection    object   1428           10591           88.118812
# boxOffice                object  12019               0            0.000000
# budget                   object  12019               0            0.000000
# director                 object  12012               7            0.058241
# distributor              object   9518            2501           20.808720
# genre                    object  12019               0            0.000000
# genres                   object  12019               0            0.000000
# homepage                 object   2843            9176           76.345786
# id                       object  11772             247            2.055079
# id_x                     object  12019               0            0.000000
# id_y                     object  12019               0            0.000000
# imdb_id                  object  12017               2            0.016640
# originalLanguage         object  12004              15            0.124802
# original_language        object  12019               0            0.000000
# original_title           object  12019               0            0.000000
# overview                 object  11971              48            0.399368
# popularity               object  12019               0            0.000000
# poster_path              object  12006              13            0.108162
# production_companies     object  12019               0            0.000000
# production_countries     object  12019               0            0.000000
# rating                   object   6345            5674           47.208586
# ratingContents           object   6345            5674           47.208586
# releaseDateStreaming     object  11611             408            3.394625
# releaseDateTheaters      object  10153            1866           15.525418
# release_date             object  12019               0            0.000000
# revenue                 float64  12019               0            0.000000
# review_count            float64  11772             247            2.055079
# runtime                 float64  12017               2            0.016640
# runtimeMinutes          float64  12014               5            0.041601
# soundMix                 object   8139            3880           32.282220
# spoken_languages         object  12019               0            0.000000
# status                   object  12008              11            0.091522
# tagline                  object   8383            3636           30.252101
# title                    object  12019               0            0.000000
# tomatoMeter             float64  11437             582            4.842333
# video                    object  12019               0            0.000000
# vote_average            float64  12019               0            0.000000
# vote_count              float64  12019               0            0.000000
# writer                   object  10635            1384           11.515101
#
#                        Unique Values  Unique Rate          Mean  Median  \
# Cast                            7144    59.439221           NaN     NaN
# Director                        3645    30.326982           NaN     NaN
# Genre                            749     6.231800           NaN     NaN
# Origin/Ethnicity                  20     0.166403           NaN     NaN
# Plot                            7153    59.514103           NaN     NaN
# Release Year                     107     0.890257  1.994003e+03  2000.0
# Title                           6349    52.824694           NaN     NaN
# Wiki Page                       7160    59.572344           NaN     NaN
# adult                              1     0.008320           NaN     NaN
# audienceScore                     94     0.782095  6.003028e+01    61.0
# belongs_to_collection            615     5.116898           NaN     NaN
# boxOffice                       2718    22.614194           NaN     NaN
# budget                           466     3.877194           NaN     NaN
# director                        3098    25.775855           NaN     NaN
# distributor                      810     6.739329           NaN     NaN
# genre                            647     5.383143           NaN     NaN
# genres                          1540    12.813046           NaN     NaN
# homepage                        1934    16.091189           NaN     NaN
# id                              6509    54.155920           NaN     NaN
# id_x                            6635    55.204260           NaN     NaN
# id_y                            7859    65.388135           NaN     NaN
# imdb_id                         7858    65.379815           NaN     NaN
# originalLanguage                  46     0.382727           NaN     NaN
# original_language                 44     0.366087           NaN     NaN
# original_title                  6800    56.577086           NaN     NaN
# overview                        7827    65.121890           NaN     NaN
# popularity                      7855    65.354855           NaN     NaN
# poster_path                     7851    65.321574           NaN     NaN
# production_companies            5483    45.619436           NaN     NaN
# production_countries             633     5.266661           NaN     NaN
# rating                             4     0.033281           NaN     NaN
# ratingContents                  2718    22.614194           NaN     NaN
# releaseDateStreaming            1552    12.912888           NaN     NaN
# releaseDateTheaters             2433    20.242949           NaN     NaN
# release_date                    4797    39.911806           NaN     NaN
# revenue                         4154    34.561944  4.804579e+07     0.0
# review_count                     375     3.120060  9.133265e+01    64.0
# runtime                          208     1.730593  1.052753e+02   102.0
# runtimeMinutes                   136     1.131542  1.072383e+02   104.0
# soundMix                         415     3.452866           NaN     NaN
# spoken_languages                 640     5.324902           NaN     NaN
# status                             4     0.033281           NaN     NaN
# tagline                         5730    47.674515           NaN     NaN
# title                           6307    52.475248           NaN     NaN
# tomatoMeter                      101     0.840336  5.554184e+01    58.0
# video                              1     0.008320           NaN     NaN
# vote_average                      77     0.640652  5.999068e+00     6.2
# vote_count                      1606    13.362177  4.025483e+02    58.0
# writer                          4715    39.229553           NaN     NaN
#
#                                                                     Mode  \
# Cast                   Bill Condon (director/screenplay); Evan Spilio...
# Director                                                         Unknown
# Genre                                                              drama
# Origin/Ethnicity                                                American
# Plot                   After losing her mother at a young age, Ella p...
# Release Year                                                      2011.0
# Title                                                         Cinderella
# Wiki Page              https://en.wikipedia.org/wiki/Cinderella_(2015...
# adult                                                              False
# audienceScore                                                       80.0
# belongs_to_collection  {'id': 645, 'name': 'James Bond Collection', '...
# boxOffice                                                          $1.1M
# budget                                                                 0
# director                                                 Kenneth Branagh
# distributor                                           Paramount Pictures
# genre                                                              Drama
# genres                                     [{'id': 18, 'name': 'Drama'}]
# homepage                             http://movies.disney.com/cinderella
# id                                                            cinderella
# id_x                                                          cinderella
# id_y                                                              105045
# imdb_id                                                        tt0111613
# originalLanguage                                                 English
# original_language                                                     en
# original_title                                                Cinderella
# overview               East-Berlin, 1961, shortly after the erection ...
# popularity                                                      0.122178
# poster_path                             /5WFIrBhOOgc0jGmoLxMZwWqCctO.jpg
# production_companies                                                  []
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...
# rating                                                                 R
# ratingContents                                              ['Language']
# releaseDateStreaming                                          2005-10-04
# releaseDateTheaters                                           1996-12-25
# release_date                                                  1996-12-25
# revenue                                                              0.0
# review_count                                                        33.0
# runtime                                                             90.0
# runtimeMinutes                                                     105.0
# soundMix                                                        Surround
# spoken_languages                [{'iso_639_1': 'en', 'name': 'English'}]
# status                                                          Released
# tagline                                          A love, a hope, a wall.
# title                                                         cinderella
# tomatoMeter                                                         88.0
# video                                                              False
# vote_average                                                         6.0
# vote_count                                                           2.0
# writer                                                       Chris Weitz
#
#                           Min           Max
# Cast                      NaN           NaN
# Director                  NaN           NaN
# Genre                     NaN           NaN
# Origin/Ethnicity          NaN           NaN
# Plot                      NaN           NaN
# Release Year           1903.0  2.017000e+03
# Title                     NaN           NaN
# Wiki Page                 NaN           NaN
# adult                     NaN           NaN
# audienceScore             0.0  1.000000e+02
# belongs_to_collection     NaN           NaN
# boxOffice                 NaN           NaN
# budget                    NaN           NaN
# director                  NaN           NaN
# distributor               NaN           NaN
# genre                     NaN           NaN
# genres                    NaN           NaN
# homepage                  NaN           NaN
# id                        NaN           NaN
# id_x                      NaN           NaN
# id_y                      NaN           NaN
# imdb_id                   NaN           NaN
# originalLanguage          NaN           NaN
# original_language         NaN           NaN
# original_title            NaN           NaN
# overview                  NaN           NaN
# popularity                NaN           NaN
# poster_path               NaN           NaN
# production_companies      NaN           NaN
# production_countries      NaN           NaN
# rating                    NaN           NaN
# ratingContents            NaN           NaN
# releaseDateStreaming      NaN           NaN
# releaseDateTheaters       NaN           NaN
# release_date              NaN           NaN
# revenue                   0.0  2.787965e+09
# review_count              1.0  9.540000e+02
# runtime                   0.0  8.770000e+02
# runtimeMinutes           17.0  2.420000e+02
# soundMix                  NaN           NaN
# spoken_languages          NaN           NaN
# status                    NaN           NaN
# tagline                   NaN           NaN
# title                     NaN           NaN
# tomatoMeter               0.0  1.000000e+02
# video                     NaN           NaN
# vote_average              0.0  1.000000e+01
# vote_count                0.0  1.407500e+04
# writer                    NaN           NaN
